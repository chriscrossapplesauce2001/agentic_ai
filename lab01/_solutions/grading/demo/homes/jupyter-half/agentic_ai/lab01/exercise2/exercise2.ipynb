# %% [markdown]
# # Exercise 2 - ReAct loop

# %%
def run_agent(query):
    messages = [{'role':'user','content':query}]
    while True:
        response = ollama.chat(model='m', messages=messages, tools=tools)
        msg = response.message
        if msg.tool_calls:
            pass  # TODO3: run the tool and append the result
        return None  # TODO4: read the final answer
